# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
# !pip install -q ultralytics roboflow
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 20.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.8/95.8 kB 10.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 18.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 80.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 95.3 MB/s eta 0:00:00

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="44TqYLbY9NRpkO40PC35")
project = rf.workspace("yoloegitim").project("pdf_gorsel_algilama")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# !find /content -name "data.yaml"
# Out:
# /content/pdf_gorsel_algilama-2/data.yaml

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="/content/pdf_gorsel_algilama-2/data.yaml",
    epochs=50,
    imgsz=640
)
# Out:
# Ultralytics 8.4.21 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
model = YOLO("/content/runs/detect/train3//weights/best.pt")
results = model.predict(
    source = "/content/pdf_gorsel_algilama-2/test/images/page_3_png.rf.559ee5699fb781a82efd3246247c3964.jpg",
    conf = 0.25,
    save = True
)
# Out:
# image 1/1 /content/pdf_gorsel_algilama-2/test/images/page_3_png.rf.559ee5699fb781a82efd3246247c3964.jpg: 640x640 1 images, 9.0ms
# Speed: 2.3ms preprocess, 9.0ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/runs/detect/predict2
