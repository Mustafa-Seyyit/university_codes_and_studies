# %%
import mglearn
import matplotlib.pyplot as plt

mglearn.plots.plot_kmeans_algorithm()

plt.show()

# %%
from sklearn.datasets import load_iris
import pandas as pd

iris = load_iris()

df = pd.DataFrame(
    iris.data,
    columns=iris.feature_names
)

# %%
print(df.shape)
# Out:
# (150, 4)

# %%
print(df.columns)
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)'],
#       dtype='object')

# %%
print(iris.target_names)
# Out:
# ['setosa' 'versicolor' 'virginica']

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
from pandas.core.common import random_state
from sklearn.cluster import KMeans

wcss = []

for k in range(1, 11):

    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(df)

    wcss.append(kmeans.inertia_)

plt.figure(figsize=(8,6), dpi=600)

plt.plot(range(1, 11), wcss, marker='o')

plt.xlabel("Küme Sayısı (K)")
plt.ylabel("WCSS")
plt.title("Iris Veri Seti - Elbow Method")

plt.xticks(range(1,11))
plt.grid()
plt.show()

# %%
kmeans = KMeans(n_clusters=3, random_state=42)

kmeans.fit(df)
# Out:
# KMeans(n_clusters=3, random_state=42)

# %%
df["Kume"] = kmeans.labels_
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    Kume
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1

# %%
merkezler = pd.DataFrame(kmeans.cluster_centers_, columns=df.columns[:-1])
print(merkezler)
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0           6.853846          3.076923           5.715385          2.053846
# 1           5.006000          3.428000           1.462000          0.246000
# 2           5.883607          2.740984           4.388525          1.434426

# %%
plt.figure(figsize=(8,6), dpi=600)

plt.scatter(
        df["petal length (cm)"],
        df["petal width (cm)"],
        c=df["Kume"],
)

plt.scatter(
        kmeans.cluster_centers_[:,2],
        kmeans.cluster_centers_[:,3],
        s=50,
        c="red",
        marker='o',
        label="Küme Merkezi"
)

plt.xlabel("Petal Lenght")
plt.ylabel("Petal Width")
plt.title("K-Means Kümeleme (Iris Veri Seti)")

plt.legend()
plt.show()

# %%
from sklearn.metrics import confusion_matrix

gercek = iris.target

tahmin = kmeans.labels_

cm = confusion_matrix(gercek, tahmin)

cm_df = pd.DataFrame(
        cm,
        index=iris.target_names,
        columns=["Küme 0", "Küme 1", "Küme 2"]
)

print(cm_df)
# Out:
#             Küme 0  Küme 1  Küme 2
# setosa           0      50       0
# versicolor       3       0      47
# virginica       36       0      14
